# %% [markdown]
# ## Students Information
#
# Please enter the names and IDs of the two students below:
#
# 1. **Name**: Donia Gameel Mahmoud
#    **ID**: `9202523`
#
# 2. **Name**: Heba Ashrar Raslan
#    **ID**: `9203667`

# %% [markdown]
# ## Students Instructions
#
# This is your last graded lab assignment, as you put the work you have studied in the lectures in action, please take this opportunity to enhance your understanding of the concepts and hone your skills. As you work on your assignment, please keep the following instructions in mind:
#
# - Clearly state your personal information where indicated.
# - Be ready with your work before the time of the next discussion slot in the schedule.
# - Plagiarism will be met with penalties, refrain from copying any answers to make the most out of the assignment. If any signs of plagiarism are detected, actions will be taken.
# - It is acceptable to share the workload of the assignment bearing the discussion in mind.
# - Feel free to [reach out](mailto:cmpsy27@gmail.com) if there were any ambiguities or post on the classroom.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this assignment. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed assignments and wish you the best of luck!

# %% [markdown]
# ## Installation Instructions
#
# In this lab assignment, we require additional Python libraries for machine learning (ML) and deep learning (DL) algorithms and frameworks. To fulfill these requirements, we need to install Pytorch.
# 1. Install Pytorch \
# PyTorch is a versatile and powerful machine learning library for Python, known for its flexibility and ease of use in research and production. It supports various deep learning operations and models, including convolutional and recurrent neural networks. For Windows users, the installation also requires ensuring that CUDA, provided by NVIDIA, is compatible to enable GPU acceleration. This enhances performance significantly, particularly in training large neural networks.\
# For windows installation with GPU support you can [check out this link](https://pytorch.org/get-started/locally/) which is the source for the command below and please know that support for GPU is done for windows so you can also check out [previous versions](https://pytorch.org/get-started/previous-versions/), you could use CPU on windows smoothly, use linux or resort to [WSL](https://www.youtube.com/watch?v=R4m8YEixidI).
#
# ```bash
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# ```
# ```bash
# conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
# ```

# %% [markdown]
# > **Note:** You are allowed to install any other necessary libraries you deem useful for solving the lab. Please ensure that any additional libraries are compatible with the assignment requirements and are properly documented in your submission.

# %% [markdown]
# ## U-Net
#
# U-Net is a convolutional neural network designed specifically for biomedical image segmentation. First introduced in a 2015 paper by Olaf Ronneberger, Philipp Fischer, and Thomas Brox, its architecture is notably shaped like the letter "U", which inspired its name. This structure comprises a contracting path to capture context and a symmetrically expanding path that aids in precise localization, making it particularly adept at leveraging small datasets to achieve highly accurate segmentations. U-Net's ability to accurately segment various tissues and medical conditions has made it a staple in medical imaging and has spurred adaptations for broader image analysis applications. Its success in the medical domain demonstrates its potential for high-impact applications in other fields requiring detailed image segmentation.
#
# U-Net's robust architecture has found significant applications in the field of satellite imaging as well. The ability of U-Net to effectively handle multi-scale and high-resolution images makes it particularly suitable for satellite image analysis. In satellite imaging, U-Net is commonly used for tasks such as land cover classification, road detection, and building segmentation. Its structure allows for precise segmentation of complex objects from high-resolution satellite imagery, even with relatively limited labeled datasets. This capability is crucial in environmental monitoring, urban planning, and disaster management, where accurate and detailed image analysis is required. The adaptability and efficiency of U-Net in handling spatial hierarchies and various textures present in satellite images highlight its versatility and effectiveness beyond its initial medical context.

# %% [markdown]
# ### U-Net Architecture
#
# ![U-Net Architecture](unet.jpg)

# %% [markdown]
# ### Detailed Overview of Functions in `utilities.py`
#
# The `utilities.py` file contains multiple functions to support image processing, data manipulation, and neural network training:
#
# - **`generate_random_data(height, width, count)`**:
#   - Generates random images and masks.
#
# - **`generate_img_and_mask(height, width)`**:
#   - Generates a single image and corresponding mask.
#
# - **`add_square(img, mask)`**:
#   - Adds a square to an image and updates the mask.
#
# - **`add_filled_square(img, mask)`**:
#   - Adds a filled square to an image and updates the mask.
#
# - **`logical_and(mask1, mask2)`**:
#   - Performs logical 'AND' operation between two masks.
#
# - **`add_mesh_square(img, mask)`**:
#   - Adds a mesh-patterned square to an image and updates the mask.
#
# - **`add_triangle(img, mask)`**:
#   - Adds a triangle to an image and updates the mask.
#
# - **`add_circle(img, mask)`**:
#   - Adds a circle to an image and updates the mask.
#
# - **`add_plus(img, mask)`**:
#   - Adds a plus sign to an image and updates the mask.
#
# - **`get_random_location(shape, zoom)`**:
#   - Gets a random location within an image shape.
#
# - **`plot_img_array(img_array, n_col)`**:
#   - Plots an array of images.
#
# - **`plot_side_by_side(img_arrays)`**:
#   - Plots images side by side for comparison.
#
# - **`plot_errors(train_losses, val_losses)`**:
#   - Plots training and validation loss errors.
#
# - **`masks_to_colorimg(masks)`**:
#   - Converts masks to colored images.
#
# - **`generate_images_and_masks_then_plot()`**:
#   - Generates images and masks and plots them.
#
# - **`reverse_transform(transform)`**:
#   - Reverses a transformation applied to an image.
#
# - **`get_data_loaders(train_dir, valid_dir, batch_size)`**:
#   - Gets data loaders for training and validation datasets.
#
# - **`dice_loss(inputs, targets, smooth)`**:
#   - Calculates Dice loss for model evaluation.
#
# - **`calc_loss(pred, target, metrics)`**:
#   - Calculates loss and updates metrics.
#
# - **`print_metrics(metrics, epoch_samples, phase)`**:
#   - Prints metrics for training or validation phases.
#
# - **`train_model(model, dataloaders, criterion, optimizer, num_epochs)`**:
#   - Trains a model given data loaders and training parameters.
#
# - **`run(model)`**:
#   - Runs a full model training and evaluation session.
#
# - **`__init__`, `__len__`, `__getitem__`**:
#   - Standard class methods used in Python classes, typically for data handling or model initialization.
#
# These functions collectively facilitate the full lifecycle of processing, training, and evaluating neural network models, particularly focusing on image-related tasks.

# %% [markdown]
# The primary objective of this assignment is to develop a neural network model capable of performing accurate image segmentation. Image segmentation involves dividing an image into segments that represent different objects or regions, which is crucial in various applications such as medical imaging, autonomous driving, and satellite image analysis.
#
# #### Image and Mask Generation
# In this assignment, synthetic images along with corresponding segmentation masks are generated to train and evaluate the segmentation model. Each image typically includes multiple geometric shapes placed randomly. These shapes can include simple forms such as circles, squares, and triangles, or more complex designs.
#
# #### Masks and Their Role in Segmentation
# - **Mask Generation**: Alongside each synthetic image, a mask is generated where each shape in the image has a corresponding segment in the mask. Each segment in the mask is represented by a unique color or grayscale intensity, where each intensity level corresponds to a different class (shape).
# - **Function of the Mask**: The mask serves as a "ground truth" for training the segmentation model. The model learns to predict these masks from the input images. Essentially, the task of the model is to map the input image to its corresponding output mask, segmenting the shapes it has learned during training.
# - **Learning Process**: During training, the model adjusts its parameters to minimize the difference between its predicted masks and the ground truth masks. This process involves optimizing a loss function, typically using backpropagation.

# %% [markdown]
# ## Requirement - U-Net Application
# - **Implement or Use U-Net**:
#   - **Option 1: Implementation** - Students are encouraged to implement the U-Net architecture from scratch, including defining all the layers and connections based on the standard specifications found in the literature.
#   - **Option 2: Use Pre-existing Implementation** - Students may also opt to use an existing implementation of U-Net. This can include adapting an open-source model available in frameworks like PyTorch.
#
# - **Integration with `utilities.py`**:
#   - The U-Net model, whether self-implemented or pre-existing, must be integrated with the `utilities.py` script provided. This integration is essential for processing data, training the model, and evaluating its performance efficiently.
#   - The model should effectively process input images and produce accurate segmentation masks as output, corresponding to the different segments of the input images.
#   - **You can make any necessary modifications including writing your own training loop for example**.

# %%
# import libraries here
import torch
import torch.nn as nn
from torchvision import models
import torch.nn.functional as F

# %%
import torch.nn as nn

class UNet(nn.Module):
    def __init__(self, n_class):
        super().__init__()
        # Define U-Net architecture with increased complexity
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(512, 1024, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(1024, 1024, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(64, n_class, kernel_size=1),
        )


    def forward(self, x):
        # Forward pass through encoder
        encoder_out = self.encoder(x)

        # Forward pass through decoder
        decoder_out = self.decoder(encoder_out)

        return decoder_out

# %%
import utilities

utilities.run(UNet)
# Out:
# Epoch 0/119
# ----------
# LR 0.0001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: bce: 0.708414, dice: 0.990834, jaccard: 0.004134, loss: 0.849624
# val: bce: 0.708280, dice: 0.990857, jaccard: 0.004151, loss: 0.849568
# saving best model
# 0m 3s
# Epoch 1/119
# ----------
# LR 1e-05
# train: bce: 0.708201, dice: 0.990834, jaccard: 0.004134, loss: 0.849517
# val: bce: 0.708066, dice: 0.990857, jaccard: 0.004151, loss: 0.849461
# saving best model
# 0m 2s
# Epoch 2/119
# ----------
# LR 1e-05
# train: bce: 0.707987, dice: 0.990834, jaccard: 0.004134, loss: 0.849411
# val: bce: 0.707852, dice: 0.990857, jaccard: 0.004151, loss: 0.849354
# saving best model
# 0m 2s
# Epoch 3/119
# ----------
# LR 1e-05
# train: bce: 0.707772, dice: 0.990834, jaccard: 0.004134, loss: 0.849303
# val: bce: 0.707636, dice: 0.990857, jaccard: 0.004151, loss: 0.849247
# saving best model
# 0m 2s
# Epoch 4/119
# ----------
# LR 1e-05
# train: bce: 0.707556, dice: 0.990834, jaccard: 0.004134, loss: 0.849195
# val: bce: 0.707418, dice: 0.990857, jaccard: 0.004151, loss: 0.849138
# saving best model
# 0m 2s
# Epoch 5/119
# ----------
# LR 1e-05
# train: bce: 0.707338, dice: 0.990834, jaccard: 0.004134, loss: 0.849086
# val: bce: 0.707199, dice: 0.990857, jaccard: 0.004151, loss: 0.849028
# saving best model
# 0m 2s
# Epoch 6/119
# ----------
# LR 1e-05
# train: bce: 0.707118, dice: 0.990834, jaccard: 0.004134, loss: 0.848976
# val: bce: 0.706978, dice: 0.990857, jaccard: 0.004151, loss: 0.848917
# saving best model
# 0m 2s
# Epoch 7/119
# ----------
# LR 1e-05
# train: bce: 0.706896, dice: 0.990834, jaccard: 0.004134, loss: 0.848865
# val: bce: 0.706756, dice: 0.990857, jaccard: 0.004151, loss: 0.848806
# saving best model
# 0m 2s
# Epoch 8/119
# ----------
# LR 1e-05
# train: bce: 0.706673, dice: 0.990834, jaccard: 0.004134, loss: 0.848754
# val: bce: 0.706532, dice: 0.990857, jaccard: 0.004151, loss: 0.848695
# saving best model
# 0m 2s
# Epoch 9/119
# ----------
# LR 1e-05
# train: bce: 0.706450, dice: 0.990834, jaccard: 0.004134, loss: 0.848642
# val: bce: 0.706309, dice: 0.990857, jaccard: 0.004151, loss: 0.848583
# saving best model
# 0m 2s
# Epoch 10/119
# ----------
# LR 1e-05
# train: bce: 0.706226, dice: 0.990834, jaccard: 0.004134, loss: 0.848530
# val: bce: 0.706082, dice: 0.990857, jaccard: 0.004151, loss: 0.848469
# saving best model
# 0m 2s
# Epoch 11/119
# ----------
# LR 1e-05
# train: bce: 0.705998, dice: 0.990834, jaccard: 0.004134, loss: 0.848416
# val: bce: 0.705852, dice: 0.990857, jaccard: 0.004151, loss: 0.848355
# saving best model
# 0m 2s
# Epoch 12/119
# ----------
# LR 1e-05
# train: bce: 0.705767, dice: 0.990834, jaccard: 0.004134, loss: 0.848301
# val: bce: 0.705620, dice: 0.990857, jaccard: 0.004151, loss: 0.848238
# saving best model
# 0m 2s
# Epoch 13/119
# ----------
# LR 1e-05
# train: bce: 0.705533, dice: 0.990834, jaccard: 0.004134, loss: 0.848184
# val: bce: 0.705384, dice: 0.990857, jaccard: 0.004151, loss: 0.848121
# saving best model
# 0m 2s
# Epoch 14/119
# ----------
# LR 1e-05
# train: bce: 0.705296, dice: 0.990834, jaccard: 0.004134, loss: 0.848065
# val: bce: 0.705145, dice: 0.990857, jaccard: 0.004151, loss: 0.848001
# saving best model
# 0m 2s
# Epoch 15/119
# ----------
# LR 1e-05
# train: bce: 0.705057, dice: 0.990834, jaccard: 0.004134, loss: 0.847945
# val: bce: 0.704903, dice: 0.990857, jaccard: 0.004151, loss: 0.847880
# saving best model
# 0m 2s
# Epoch 16/119
# ----------
# LR 1e-05
# train: bce: 0.704814, dice: 0.990834, jaccard: 0.004134, loss: 0.847824
# val: bce: 0.704658, dice: 0.990857, jaccard: 0.004151, loss: 0.847758
# saving best model
# 0m 2s
# Epoch 17/119
# ----------
# LR 1e-05
# train: bce: 0.704567, dice: 0.990834, jaccard: 0.004134, loss: 0.847701
# val: bce: 0.704410, dice: 0.990857, jaccard: 0.004151, loss: 0.847633
# saving best model
# 0m 2s
# Epoch 18/119
# ----------
# LR 1e-05
# train: bce: 0.704317, dice: 0.990834, jaccard: 0.004134, loss: 0.847576
# val: bce: 0.704157, dice: 0.990857, jaccard: 0.004151, loss: 0.847507
# saving best model
# 0m 2s
# Epoch 19/119
# ----------
# LR 1e-05
# train: bce: 0.704062, dice: 0.990834, jaccard: 0.004134, loss: 0.847448
# val: bce: 0.703898, dice: 0.990857, jaccard: 0.004151, loss: 0.847378
# saving best model
# 0m 2s
# Epoch 20/119
# ----------
# LR 1e-05
# train: bce: 0.703801, dice: 0.990834, jaccard: 0.004134, loss: 0.847318
# val: bce: 0.703634, dice: 0.990857, jaccard: 0.004151, loss: 0.847246
# saving best model
# 0m 2s
# Epoch 21/119
# ----------
# LR 1e-05
# train: bce: 0.703535, dice: 0.990834, jaccard: 0.004134, loss: 0.847185
# val: bce: 0.703362, dice: 0.990857, jaccard: 0.004151, loss: 0.847110
# saving best model
# 0m 2s
# Epoch 22/119
# ----------
# LR 1e-05
# train: bce: 0.703259, dice: 0.990834, jaccard: 0.004134, loss: 0.847047
# val: bce: 0.703080, dice: 0.990857, jaccard: 0.004151, loss: 0.846969
# saving best model
# 0m 2s
# Epoch 23/119
# ----------
# LR 1e-05
# train: bce: 0.702973, dice: 0.990835, jaccard: 0.004134, loss: 0.846904
# val: bce: 0.702789, dice: 0.990857, jaccard: 0.004151, loss: 0.846823
# saving best model
# 0m 2s
# Epoch 24/119
# ----------
# LR 1e-05
# train: bce: 0.702680, dice: 0.990835, jaccard: 0.004134, loss: 0.846757
# val: bce: 0.702489, dice: 0.990858, jaccard: 0.004151, loss: 0.846673
# saving best model
# 0m 2s
# Epoch 25/119
# ----------
# LR 1e-05
# train: bce: 0.702375, dice: 0.990835, jaccard: 0.004134, loss: 0.846605
# val: bce: 0.702174, dice: 0.990858, jaccard: 0.004151, loss: 0.846516
# saving best model
# 0m 2s
# Epoch 26/119
# ----------
# LR 1e-05
# train: bce: 0.702053, dice: 0.990835, jaccard: 0.004134, loss: 0.846444
# val: bce: 0.701842, dice: 0.990858, jaccard: 0.004151, loss: 0.846350
# saving best model
# 0m 2s
# Epoch 27/119
# ----------
# LR 1e-05
# train: bce: 0.701714, dice: 0.990835, jaccard: 0.004134, loss: 0.846275
# val: bce: 0.701492, dice: 0.990858, jaccard: 0.004151, loss: 0.846175
# saving best model
# 0m 2s
# Epoch 28/119
# ----------
# LR 1e-05
# train: bce: 0.701357, dice: 0.990835, jaccard: 0.004134, loss: 0.846096
# val: bce: 0.701121, dice: 0.990858, jaccard: 0.004151, loss: 0.845989
# saving best model
# 0m 2s
# Epoch 29/119
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.700975, dice: 0.990835, jaccard: 0.004134, loss: 0.845905
# val: bce: 0.700715, dice: 0.990858, jaccard: 0.004151, loss: 0.845787
# saving best model
# 0m 2s
# Epoch 30/119
# ----------
# LR 1e-05
# train: bce: 0.700551, dice: 0.990835, jaccard: 0.004134, loss: 0.845693
# val: bce: 0.700259, dice: 0.990858, jaccard: 0.004151, loss: 0.845559
# saving best model
# 0m 2s
# Epoch 31/119
# ----------
# LR 1e-05
# train: bce: 0.700067, dice: 0.990835, jaccard: 0.004134, loss: 0.845451
# val: bce: 0.699712, dice: 0.990859, jaccard: 0.004151, loss: 0.845285
# saving best model
# 0m 2s
# Epoch 32/119
# ----------
# LR 1e-05
# train: bce: 0.699453, dice: 0.990836, jaccard: 0.004134, loss: 0.845144
# val: bce: 0.698946, dice: 0.990859, jaccard: 0.004151, loss: 0.844903
# saving best model
# 0m 2s
# Epoch 33/119
# ----------
# LR 1e-05
# train: bce: 0.698519, dice: 0.990837, jaccard: 0.004134, loss: 0.844678
# val: bce: 0.697600, dice: 0.990861, jaccard: 0.004151, loss: 0.844231
# saving best model
# 0m 2s
# Epoch 34/119
# ----------
# LR 1e-05
# train: bce: 0.696602, dice: 0.990841, jaccard: 0.004134, loss: 0.843721
# val: bce: 0.694193, dice: 0.990868, jaccard: 0.004151, loss: 0.842531
# saving best model
# 0m 2s
# Epoch 35/119
# ----------
# LR 1e-05
# train: bce: 0.691221, dice: 0.990853, jaccard: 0.004134, loss: 0.841037
# val: bce: 0.683843, dice: 0.990891, jaccard: 0.004024, loss: 0.837367
# saving best model
# 0m 2s
# Epoch 36/119
# ----------
# LR 1e-05
# train: bce: 0.674289, dice: 0.990897, jaccard: 0.003510, loss: 0.832593
# val: bce: 0.650270, dice: 0.990981, jaccard: 0.001994, loss: 0.820625
# saving best model
# 0m 2s
# Epoch 37/119
# ----------
# LR 1e-05
# train: bce: 0.620034, dice: 0.991070, jaccard: 0.001656, loss: 0.805552
# val: bce: 0.548299, dice: 0.991367, jaccard: 0.001418, loss: 0.769833
# saving best model
# 0m 2s
# Epoch 38/119
# ----------
# LR 1e-05
# train: bce: 0.474547, dice: 0.991892, jaccard: 0.001199, loss: 0.733219
# val: bce: 0.329950, dice: 0.993221, jaccard: 0.001381, loss: 0.661586
# saving best model
# 0m 2s
# Epoch 39/119
# ----------
# LR 1e-05
# train: bce: 0.243018, dice: 0.994777, jaccard: 0.001315, loss: 0.618898
# val: bce: 0.127565, dice: 0.997182, jaccard: 0.001927, loss: 0.562373
# saving best model
# 0m 2s
# Epoch 40/119
# ----------
# LR 1e-05
# train: bce: 0.103731, dice: 0.997717, jaccard: 0.000530, loss: 0.550724
# val: bce: 0.090353, dice: 0.997804, jaccard: 0.000000, loss: 0.544079
# saving best model
# 0m 2s
# Epoch 41/119
# ----------
# LR 1e-05
# train: bce: 0.104189, dice: 0.997490, jaccard: 0.000000, loss: 0.550840
# val: bce: 0.119492, dice: 0.996981, jaccard: 0.000000, loss: 0.558236
# 0m 2s
# Epoch 42/119
# ----------
# LR 1e-05
# train: bce: 0.123365, dice: 0.996903, jaccard: 0.000000, loss: 0.560134
# val: bce: 0.115152, dice: 0.996941, jaccard: 0.000000, loss: 0.556046
# 0m 2s
# Epoch 43/119
# ----------
# LR 1e-05
# train: bce: 0.108213, dice: 0.997150, jaccard: 0.000000, loss: 0.552681
# val: bce: 0.089905, dice: 0.997543, jaccard: 0.000000, loss: 0.543724
# saving best model
# 0m 2s
# Epoch 44/119
# ----------
# LR 1e-05
# train: bce: 0.083327, dice: 0.997811, jaccard: 0.000000, loss: 0.540569
# val: bce: 0.071413, dice: 0.998193, jaccard: 0.000000, loss: 0.534803
# saving best model
# 0m 2s
# Epoch 45/119
# ----------
# LR 1e-05
# train: bce: 0.069711, dice: 0.998294, jaccard: 0.000000, loss: 0.534003
# val: bce: 0.066471, dice: 0.998361, jaccard: 0.000000, loss: 0.532416
# saving best model
# 0m 2s
# Epoch 46/119
# ----------
# LR 1e-05
# train: bce: 0.068009, dice: 0.998253, jaccard: 0.000000, loss: 0.533131
# val: bce: 0.068923, dice: 0.998160, jaccard: 0.000000, loss: 0.533541
# 0m 2s
# Epoch 47/119
# ----------
# LR 1e-05
# train: bce: 0.069982, dice: 0.998070, jaccard: 0.000000, loss: 0.534026
# val: bce: 0.069092, dice: 0.998120, jaccard: 0.000000, loss: 0.533606
# 0m 2s
# Epoch 48/119
# ----------
# LR 1e-05
# train: bce: 0.068505, dice: 0.998126, jaccard: 0.000000, loss: 0.533316
# val: bce: 0.065691, dice: 0.998298, jaccard: 0.000000, loss: 0.531995
# saving best model
# 0m 2s
# Epoch 49/119
# ----------
# LR 1e-05
# train: bce: 0.065127, dice: 0.998313, jaccard: 0.000000, loss: 0.531720
# val: bce: 0.063057, dice: 0.998428, jaccard: 0.000000, loss: 0.530742
# saving best model
# 0m 2s
# Epoch 50/119
# ----------
# LR 1e-05
# train: bce: 0.063300, dice: 0.998402, jaccard: 0.000000, loss: 0.530851
# val: bce: 0.062401, dice: 0.998423, jaccard: 0.000000, loss: 0.530412
# saving best model
# 0m 2s
# Epoch 51/119
# ----------
# LR 1e-05
# train: bce: 0.062934, dice: 0.998388, jaccard: 0.000000, loss: 0.530661
# val: bce: 0.062071, dice: 0.998392, jaccard: 0.000000, loss: 0.530232
# saving best model
# 0m 2s
# Epoch 52/119
# ----------
# LR 1e-05
# train: bce: 0.062384, dice: 0.998371, jaccard: 0.000000, loss: 0.530377
# val: bce: 0.061275, dice: 0.998395, jaccard: 0.000000, loss: 0.529835
# saving best model
# 0m 2s
# Epoch 53/119
# ----------
# LR 1e-05
# train: bce: 0.061472, dice: 0.998378, jaccard: 0.000000, loss: 0.529925
# val: bce: 0.060391, dice: 0.998407, jaccard: 0.000000, loss: 0.529399
# saving best model
# 0m 2s
# Epoch 54/119
# ----------
# LR 1e-05
# train: bce: 0.060585, dice: 0.998378, jaccard: 0.000000, loss: 0.529481
# val: bce: 0.059739, dice: 0.998403, jaccard: 0.000000, loss: 0.529071
# saving best model
# 0m 2s
# Epoch 55/119
# ----------
# LR 1e-05
# train: bce: 0.059941, dice: 0.998367, jaccard: 0.000000, loss: 0.529154
# val: bce: 0.059201, dice: 0.998387, jaccard: 0.000000, loss: 0.528794
# saving best model
# 0m 2s
# Epoch 56/119
# ----------
# LR 1e-05
# train: bce: 0.059368, dice: 0.998349, jaccard: 0.000000, loss: 0.528858
# val: bce: 0.058622, dice: 0.998369, jaccard: 0.000000, loss: 0.528495
# saving best model
# 0m 2s
# Epoch 57/119
# ----------
# LR 1e-05
# train: bce: 0.058738, dice: 0.998333, jaccard: 0.000000, loss: 0.528535
# val: bce: 0.057994, dice: 0.998351, jaccard: 0.000000, loss: 0.528173
# saving best model
# 0m 2s
# Epoch 58/119
# ----------
# LR 1e-05
# train: bce: 0.058086, dice: 0.998316, jaccard: 0.000000, loss: 0.528201
# val: bce: 0.057382, dice: 0.998331, jaccard: 0.000000, loss: 0.527857
# saving best model
# 0m 2s
# Epoch 59/119
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.057457, dice: 0.998297, jaccard: 0.000000, loss: 0.527877
# val: bce: 0.056783, dice: 0.998309, jaccard: 0.000000, loss: 0.527546
# saving best model
# 0m 2s
# Epoch 60/119
# ----------
# LR 1e-05
# train: bce: 0.056838, dice: 0.998276, jaccard: 0.000000, loss: 0.527557
# val: bce: 0.056180, dice: 0.998285, jaccard: 0.000000, loss: 0.527232
# saving best model
# 0m 2s
# Epoch 61/119
# ----------
# LR 1e-05
# train: bce: 0.056198, dice: 0.998253, jaccard: 0.000000, loss: 0.527226
# val: bce: 0.055550, dice: 0.998261, jaccard: 0.000000, loss: 0.526906
# saving best model
# 0m 2s
# Epoch 62/119
# ----------
# LR 1e-05
# train: bce: 0.055535, dice: 0.998228, jaccard: 0.000000, loss: 0.526882
# val: bce: 0.054906, dice: 0.998235, jaccard: 0.000000, loss: 0.526570
# saving best model
# 0m 2s
# Epoch 63/119
# ----------
# LR 1e-05
# train: bce: 0.054859, dice: 0.998202, jaccard: 0.000000, loss: 0.526531
# val: bce: 0.054244, dice: 0.998207, jaccard: 0.000000, loss: 0.526225
# saving best model
# 0m 2s
# Epoch 64/119
# ----------
# LR 1e-05
# train: bce: 0.054174, dice: 0.998173, jaccard: 0.000000, loss: 0.526173
# val: bce: 0.053560, dice: 0.998176, jaccard: 0.000000, loss: 0.525868
# saving best model
# 0m 2s
# Epoch 65/119
# ----------
# LR 1e-05
# train: bce: 0.053463, dice: 0.998142, jaccard: 0.000000, loss: 0.525802
# val: bce: 0.052847, dice: 0.998142, jaccard: 0.000000, loss: 0.525495
# saving best model
# 0m 2s
# Epoch 66/119
# ----------
# LR 1e-05
# train: bce: 0.052721, dice: 0.998107, jaccard: 0.000000, loss: 0.525414
# val: bce: 0.052122, dice: 0.998105, jaccard: 0.000000, loss: 0.525114
# saving best model
# 0m 2s
# Epoch 67/119
# ----------
# LR 1e-05
# train: bce: 0.051978, dice: 0.998070, jaccard: 0.000000, loss: 0.525024
# val: bce: 0.051378, dice: 0.998066, jaccard: 0.000000, loss: 0.524722
# saving best model
# 0m 2s
# Epoch 68/119
# ----------
# LR 1e-05
# train: bce: 0.051203, dice: 0.998029, jaccard: 0.000000, loss: 0.524616
# val: bce: 0.050615, dice: 0.998020, jaccard: 0.000000, loss: 0.524318
# saving best model
# 0m 2s
# Epoch 69/119
# ----------
# LR 1e-05
# train: bce: 0.050415, dice: 0.997982, jaccard: 0.000000, loss: 0.524199
# val: bce: 0.049828, dice: 0.997970, jaccard: 0.000000, loss: 0.523899
# saving best model
# 0m 2s
# Epoch 70/119
# ----------
# LR 1e-05
# train: bce: 0.049609, dice: 0.997930, jaccard: 0.000000, loss: 0.523769
# val: bce: 0.049026, dice: 0.997914, jaccard: 0.000000, loss: 0.523470
# saving best model
# 0m 2s
# Epoch 71/119
# ----------
# LR 1e-05
# train: bce: 0.048783, dice: 0.997871, jaccard: 0.000000, loss: 0.523327
# val: bce: 0.048212, dice: 0.997850, jaccard: 0.000000, loss: 0.523031
# saving best model
# 0m 2s
# Epoch 72/119
# ----------
# LR 1e-05
# train: bce: 0.047956, dice: 0.997803, jaccard: 0.000000, loss: 0.522880
# val: bce: 0.047383, dice: 0.997777, jaccard: 0.000000, loss: 0.522580
# saving best model
# 0m 2s
# Epoch 73/119
# ----------
# LR 1e-05
# train: bce: 0.047092, dice: 0.997727, jaccard: 0.000000, loss: 0.522409
# val: bce: 0.046533, dice: 0.997698, jaccard: 0.000000, loss: 0.522115
# saving best model
# 0m 2s
# Epoch 74/119
# ----------
# LR 1e-05
# train: bce: 0.046227, dice: 0.997644, jaccard: 0.000000, loss: 0.521936
# val: bce: 0.045669, dice: 0.997608, jaccard: 0.000000, loss: 0.521638
# saving best model
# 0m 2s
# Epoch 75/119
# ----------
# LR 1e-05
# train: bce: 0.045342, dice: 0.997549, jaccard: 0.000000, loss: 0.521446
# val: bce: 0.044789, dice: 0.997507, jaccard: 0.000000, loss: 0.521148
# saving best model
# 0m 2s
# Epoch 76/119
# ----------
# LR 1e-05
# train: bce: 0.044445, dice: 0.997441, jaccard: 0.000000, loss: 0.520943
# val: bce: 0.043894, dice: 0.997393, jaccard: 0.000000, loss: 0.520643
# saving best model
# 0m 2s
# Epoch 77/119
# ----------
# LR 1e-05
# train: bce: 0.043538, dice: 0.997320, jaccard: 0.000000, loss: 0.520429
# val: bce: 0.042992, dice: 0.997262, jaccard: 0.000000, loss: 0.520127
# saving best model
# 0m 2s
# Epoch 78/119
# ----------
# LR 1e-05
# train: bce: 0.042611, dice: 0.997184, jaccard: 0.000000, loss: 0.519897
# val: bce: 0.042080, dice: 0.997121, jaccard: 0.000000, loss: 0.519601
# saving best model
# 0m 2s
# Epoch 79/119
# ----------
# LR 1e-05
# train: bce: 0.041695, dice: 0.997027, jaccard: 0.000000, loss: 0.519361
# val: bce: 0.041172, dice: 0.996952, jaccard: 0.000000, loss: 0.519062
# saving best model
# 0m 2s
# Epoch 80/119
# ----------
# LR 1e-05
# train: bce: 0.040766, dice: 0.996853, jaccard: 0.000000, loss: 0.518810
# val: bce: 0.040260, dice: 0.996771, jaccard: 0.000000, loss: 0.518515
# saving best model
# 0m 2s
# Epoch 81/119
# ----------
# LR 1e-05
# train: bce: 0.039850, dice: 0.996649, jaccard: 0.000000, loss: 0.518250
# val: bce: 0.039363, dice: 0.996555, jaccard: 0.000000, loss: 0.517959
# saving best model
# 0m 2s
# Epoch 82/119
# ----------
# LR 1e-05
# train: bce: 0.038938, dice: 0.996417, jaccard: 0.000000, loss: 0.517677
# val: bce: 0.038465, dice: 0.996318, jaccard: 0.000000, loss: 0.517392
# saving best model
# 0m 2s
# Epoch 83/119
# ----------
# LR 1e-05
# train: bce: 0.038028, dice: 0.996158, jaccard: 0.000000, loss: 0.517093
# val: bce: 0.037578, dice: 0.996042, jaccard: 0.000000, loss: 0.516810
# saving best model
# 0m 2s
# Epoch 84/119
# ----------
# LR 1e-05
# train: bce: 0.037146, dice: 0.995846, jaccard: 0.000000, loss: 0.516496
# val: bce: 0.036703, dice: 0.995723, jaccard: 0.000000, loss: 0.516213
# saving best model
# 0m 2s
# Epoch 85/119
# ----------
# LR 1e-05
# train: bce: 0.036235, dice: 0.995514, jaccard: 0.000000, loss: 0.515875
# val: bce: 0.035830, dice: 0.995379, jaccard: 0.000000, loss: 0.515605
# saving best model
# 0m 2s
# Epoch 86/119
# ----------
# LR 1e-05
# train: bce: 0.035386, dice: 0.995109, jaccard: 0.000000, loss: 0.515248
# val: bce: 0.035024, dice: 0.994940, jaccard: 0.000000, loss: 0.514982
# saving best model
# 0m 2s
# Epoch 87/119
# ----------
# LR 1e-05
# train: bce: 0.034567, dice: 0.994628, jaccard: 0.000000, loss: 0.514598
# val: bce: 0.034223, dice: 0.994471, jaccard: 0.000000, loss: 0.514347
# saving best model
# 0m 2s
# Epoch 88/119
# ----------
# LR 1e-05
# train: bce: 0.033765, dice: 0.994122, jaccard: 0.000000, loss: 0.513943
# val: bce: 0.033466, dice: 0.993949, jaccard: 0.000000, loss: 0.513708
# saving best model
# 0m 2s
# Epoch 89/119
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.033022, dice: 0.993536, jaccard: 0.000000, loss: 0.513279
# val: bce: 0.032802, dice: 0.993338, jaccard: 0.000000, loss: 0.513070
# saving best model
# 0m 2s
# Epoch 90/119
# ----------
# LR 1e-05
# train: bce: 0.032376, dice: 0.992864, jaccard: 0.000000, loss: 0.512620
# val: bce: 0.032195, dice: 0.992713, jaccard: 0.000000, loss: 0.512454
# saving best model
# 0m 2s
# Epoch 91/119
# ----------
# LR 1e-05
# train: bce: 0.031807, dice: 0.992159, jaccard: 0.000000, loss: 0.511983
# val: bce: 0.031696, dice: 0.992049, jaccard: 0.000000, loss: 0.511872
# saving best model
# 0m 2s
# Epoch 92/119
# ----------
# LR 1e-05
# train: bce: 0.031333, dice: 0.991443, jaccard: 0.000000, loss: 0.511388
# val: bce: 0.031214, dice: 0.991453, jaccard: 0.000000, loss: 0.511334
# saving best model
# 0m 2s
# Epoch 93/119
# ----------
# LR 1e-05
# train: bce: 0.030906, dice: 0.990787, jaccard: 0.000000, loss: 0.510846
# val: bce: 0.030943, dice: 0.990751, jaccard: 0.000000, loss: 0.510847
# saving best model
# 0m 2s
# Epoch 94/119
# ----------
# LR 1e-05
# train: bce: 0.030583, dice: 0.990135, jaccard: 0.000000, loss: 0.510359
# val: bce: 0.030563, dice: 0.990225, jaccard: 0.000000, loss: 0.510394
# saving best model
# 0m 2s
# Epoch 95/119
# ----------
# LR 1e-05
# train: bce: 0.030154, dice: 0.989630, jaccard: 0.000000, loss: 0.509892
# val: bce: 0.030240, dice: 0.989661, jaccard: 0.000000, loss: 0.509951
# saving best model
# 0m 2s
# Epoch 96/119
# ----------
# LR 1e-05
# train: bce: 0.030021, dice: 0.988891, jaccard: 0.000000, loss: 0.509456
# val: bce: 0.029651, dice: 0.989363, jaccard: 0.000000, loss: 0.509507
# saving best model
# 0m 2s
# Epoch 97/119
# ----------
# LR 1e-05
# train: bce: 0.029482, dice: 0.988547, jaccard: 0.000000, loss: 0.509015
# val: bce: 0.029856, dice: 0.988326, jaccard: 0.000000, loss: 0.509091
# saving best model
# 0m 2s
# Epoch 98/119
# ----------
# LR 1e-05
# train: bce: 0.029313, dice: 0.987824, jaccard: 0.000000, loss: 0.508568
# val: bce: 0.029262, dice: 0.987864, jaccard: 0.000000, loss: 0.508563
# saving best model
# 0m 2s
# Epoch 99/119
# ----------
# LR 1e-05
# train: bce: 0.029192, dice: 0.986924, jaccard: 0.000000, loss: 0.508058
# val: bce: 0.028606, dice: 0.987426, jaccard: 0.000000, loss: 0.508016
# saving best model
# 0m 2s
# Epoch 100/119
# ----------
# LR 1e-05
# train: bce: 0.028704, dice: 0.986140, jaccard: 0.000000, loss: 0.507422
# val: bce: 0.028711, dice: 0.985906, jaccard: 0.000000, loss: 0.507309
# saving best model
# 0m 2s
# Epoch 101/119
# ----------
# LR 1e-05
# train: bce: 0.028321, dice: 0.984875, jaccard: 0.000000, loss: 0.506598
# val: bce: 0.028299, dice: 0.984467, jaccard: 0.000000, loss: 0.506383
# saving best model
# 0m 2s
# Epoch 102/119
# ----------
# LR 1e-05
# train: bce: 0.028036, dice: 0.983071, jaccard: 0.000000, loss: 0.505553
# val: bce: 0.027341, dice: 0.982932, jaccard: 0.000000, loss: 0.505136
# saving best model
# 0m 2s
# Epoch 103/119
# ----------
# LR 1e-05
# train: bce: 0.027741, dice: 0.980209, jaccard: 0.000000, loss: 0.503975
# val: bce: 0.026664, dice: 0.980092, jaccard: 0.000000, loss: 0.503378
# saving best model
# 0m 2s
# Epoch 104/119
# ----------
# LR 1e-05
# train: bce: 0.027105, dice: 0.976381, jaccard: 0.000000, loss: 0.501743
# val: bce: 0.026050, dice: 0.975350, jaccard: 0.000000, loss: 0.500700
# saving best model
# 0m 2s
# Epoch 105/119
# ----------
# LR 1e-05
# train: bce: 0.026526, dice: 0.970239, jaccard: 0.000000, loss: 0.498382
# val: bce: 0.025571, dice: 0.967835, jaccard: 0.000000, loss: 0.496703
# saving best model
# 0m 2s
# Epoch 106/119
# ----------
# LR 1e-05
# train: bce: 0.026119, dice: 0.960805, jaccard: 0.000000, loss: 0.493462
# val: bce: 0.025351, dice: 0.957231, jaccard: 0.000000, loss: 0.491291
# saving best model
# 0m 2s
# Epoch 107/119
# ----------
# LR 1e-05
# train: bce: 0.026096, dice: 0.949296, jaccard: 0.000000, loss: 0.487696
# val: bce: 0.025290, dice: 0.946251, jaccard: 0.000000, loss: 0.485770
# saving best model
# 0m 2s
# Epoch 108/119
# ----------
# LR 1e-05
# train: bce: 0.025808, dice: 0.938687, jaccard: 0.000000, loss: 0.482247
# val: bce: 0.026105, dice: 0.936399, jaccard: 0.000000, loss: 0.481252
# saving best model
# 0m 2s
# Epoch 109/119
# ----------
# LR 1e-05
# train: bce: 0.026272, dice: 0.930750, jaccard: 0.000000, loss: 0.478511
# val: bce: 0.025268, dice: 0.930408, jaccard: 0.000000, loss: 0.477838
# saving best model
# 0m 2s
# Epoch 110/119
# ----------
# LR 1e-05
# train: bce: 0.025578, dice: 0.925317, jaccard: 0.000000, loss: 0.475447
# val: bce: 0.026457, dice: 0.924080, jaccard: 0.000000, loss: 0.475268
# saving best model
# 0m 2s
# Epoch 111/119
# ----------
# LR 1e-05
# train: bce: 0.025544, dice: 0.920494, jaccard: 0.000019, loss: 0.473019
# val: bce: 0.026503, dice: 0.919713, jaccard: 0.000000, loss: 0.473108
# saving best model
# 0m 2s
# Epoch 112/119
# ----------
# LR 1e-05
# train: bce: 0.025269, dice: 0.916724, jaccard: 0.000372, loss: 0.470997
# val: bce: 0.024611, dice: 0.917039, jaccard: 0.000000, loss: 0.470825
# saving best model
# 0m 2s
# Epoch 113/119
# ----------
# LR 1e-05
# train: bce: 0.024819, dice: 0.913411, jaccard: 0.000717, loss: 0.469115
# val: bce: 0.024267, dice: 0.913845, jaccard: 0.000000, loss: 0.469056
# saving best model
# 0m 2s
# Epoch 114/119
# ----------
# LR 1e-05
# train: bce: 0.024968, dice: 0.910327, jaccard: 0.001610, loss: 0.467647
# val: bce: 0.023387, dice: 0.913500, jaccard: 0.000000, loss: 0.468443
# saving best model
# 0m 2s
# Epoch 115/119
# ----------
# LR 1e-05
# train: bce: 0.025202, dice: 0.907424, jaccard: 0.002375, loss: 0.466313
# val: bce: 0.024402, dice: 0.907277, jaccard: 0.000076, loss: 0.465839
# saving best model
# 0m 2s
# Epoch 116/119
# ----------
# LR 1e-05
# train: bce: 0.024471, dice: 0.904524, jaccard: 0.001730, loss: 0.464498
# val: bce: 0.026689, dice: 0.902663, jaccard: 0.000325, loss: 0.464676
# saving best model
# 0m 2s
# Epoch 117/119
# ----------
# LR 1e-05
# train: bce: 0.025037, dice: 0.901643, jaccard: 0.002961, loss: 0.463340
# val: bce: 0.025140, dice: 0.900979, jaccard: 0.000221, loss: 0.463060
# saving best model
# 0m 2s
# Epoch 118/119
# ----------
# LR 1e-05
# train: bce: 0.025489, dice: 0.898286, jaccard: 0.004323, loss: 0.461888
# val: bce: 0.024879, dice: 0.899188, jaccard: 0.000365, loss: 0.462034
# saving best model
# 0m 2s
# Epoch 119/119
# ----------
# LR 1.0000000000000002e-06
# train: bce: 0.024867, dice: 0.896782, jaccard: 0.004185, loss: 0.460824
# val: bce: 0.026012, dice: 0.895959, jaccard: 0.002640, loss: 0.460985
# saving best model
# 0m 2s
# Best metrics for the best model:
# BCE: 0.026012
# Jaccard index: 0.002640
# Dice coefficient: 0.895959
# Loss: 0.460985
# (3, 6, 192, 192)
# Average Jaccard Index for test set: 0.0265
# Average Dice Score for test set: 0.0517
# Jacard index [0.026526665315032005]
# Dice Score [0.05168236792087555]

# %% [markdown]
# ### Grading Rubric (Total: 10 Marks)
#
# The lab is graded based on the following criteria:
#
# 1. **Data Loading and Preparation (1 Mark)**
#    - Ensure reproducible results by setting seed to `27` before all randomized operations. (1 Mark)
#
# 2. **U-Net Architecture (4 Marks)**
#    - Uses appropriate U-Net Architecture to the problem with a full pipeline. (4 Marks)
#
# 3. **Hyperparameters Tuning (2 Marks)**
#    - Report evaluation metrics on validation set. (1 Mark)
#    - Analyzes results and tunes hyperparameters. (1 Mark)
#
# 4. **Model Evaluation and Understanding (3 Marks)**
#    - Reports Jaccard Index and Dice Scores for test set. (1 Mark)
#    - **Comparison amongst your peers.** Compares the model's performance against those of peers to identify strengths and areas for improvement. (2 Marks)
#
# Each section of the lab will be evaluated on completeness, and correctness in approach and analysis. Part of the rubric also includes the student's ability to explain and justify their choices and results.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this project. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed projects and wish you the best of luck!
