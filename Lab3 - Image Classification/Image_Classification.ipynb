# %% [markdown]
# ## Students Information
#
# Please enter the names and IDs of the two students below:
#
# 1. **Name**: Donia Gameel Mahmoud
#    **ID**: `9202523`
#
# 2. **Name**: Heba Ashraf Raslan
#    **ID**: `9203667`

# %% [markdown]
# ## Students Instructions
#
# This is your first graded lab assignment, as you put the work you have studied in the lectures in action, please take this opportunity to enhance your understanding of the concepts and hone your skills. As you work on your assignment, please keep the following instructions in mind:
#
# - Clearly state your personal information where indicated.
# - Be ready with your work before the time of the next discussion slot in the schedule.
# - Plagiarism will be met with penalties, refrain from copying any answers to make the most out of the assignment. If any signs of plagiarism are detected, actions will be taken.
# - It is acceptable to share the workload of the assignment bearing the discussion in mind.
# - Feel free to [reach out](mailto:cmpsy27@gmail.com) if there were any ambiguities or post on the classroom.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this project. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed projects and wish you the best of luck!

# %% [markdown]
# ## Installation Instructions
#
# In this lab assignment, we require additional Python libraries for scientific mathematics, particularly in the context of machine learning (ML) and satellite image analysis. To fulfill these requirements, we need to install Scikit-learn and Scikit-image.
# 1. Install Scikit-learn
# Scikit-learn (Sklearn) is a powerful Python library for ML tasks, offering various algorithms for classification, regression, clustering, and model evaluation. It is extensively used for analyzing satellite imagery, enabling tasks such as land cover classification and environmental parameter prediction. On the other hand, Scikit-image (Skimage) provides comprehensive tools for image processing and computer vision, facilitating tasks such as image preprocessing, feature extraction, and segmentation. These libraries are essential for extracting valuable insights from satellite images and conducting advanced analysis in scientific computing and research domains.
# ```bash
# pip install scikit-learn scikit-image
# ```

# %% [markdown]
# > **Note:** You are allowed to install any other necessary libraries you deem useful for solving the lab. Please ensure that any additional libraries are compatible with the project requirements and are properly documented in your submission.

# %% [markdown]
# ## Maximum Likelihood Estimator (MLE) Classifier
# The Maximum Likelihood Estimator (MLE) is a fundamental statistical approach used to infer the parameters of a given distribution that are most likely to result in the observed data. In the context of image classification, MLE helps to quantify the probability of observing the data within each predefined class based on their distinct statistical properties. This method is highly effective for classifying images into categories by comparing the likelihoods of the data under different model parameters, enabling the most probable class assignment.
#
# 1. **Calculate Class Priors**: Estimate the probability of each class based on the training dataset. This is expressed as:
#    $$
#    P(C_k) = \frac{N_k}{N}
#    $$
#    where \(N_k\) is the number of samples of class \(k\) and \(N\) is the total number of samples.
#
# 2. **Estimate Class-specific Parameters**: For each class, estimate parameters such as the mean \(\mu_k\) and covariance \(\Sigma_k\) of features that describe the distribution of the data:
#    $$
#    \mu_k = \frac{1}{N_k} \sum_{x \in C_k} x
#    $$
#    $$
#    \Sigma_k = \frac{1}{N_k} \sum_{x \in C_k} (x - \mu_k)(x - \mu_k)^T
#    $$
#
# 3. **Compute Likelihoods**: For a given test instance \(x\), compute the likelihood of that instance belonging to each class using the estimated parameters:
#    $$
#    p(x | C_k) = \frac{1}{(2\pi)^{d/2} |\Sigma_k|^{1/2}} \exp\left(-\frac{1}{2} (x - \mu_k)^T \Sigma_k^{-1} (x - \mu_k)\right)
#    $$
#
# 4. **Classify Based on Maximum Likelihood**: Assign the class label to each test instance based on the highest likelihood, which can be calculated as:
#    $$
#    \hat{y} = \arg\max_{k} P(C_k) \cdot p(x | C_k)
#    $$
#
# The Naive Bayes classifier is perhaps the most well-known application of the Maximum Likelihood Estimator principle in classification tasks. It assumes that the features in each class are independent, simplifying the computation of likelihoods. While Naive Bayes is popular for its simplicity and efficiency, it is not the only technique that leverages the MLE approach. Other classical alternatives include Logistic Regression, which applies MLE to estimate the parameters that best predict categorical outcomes, and Gaussian Mixture Models, which use MLE to estimate the parameters of multiple Gaussian distributions within the data. Students are encouraged to explore these models to gain a deeper understanding of statistical estimation techniques.

# %% [markdown]
# ## Req- Image Classification for EuroSATallBands
# Image classification is a key challenge in satellite imaging and remote sensing. As discussed in the lecture, this task is typically conducted on a pixel-wise basis because a single image can contain multiple textural elements of different celestial features. However, for this specific assignment, we will focus on identifying the dominant phenomena in the image as the basis for classification.
#
# - **Load the Images**: Load the images of the EuroSAT dataset that belong to the **residential**, **river**, and **forest** classes.
#
# - **Split the Dataset**: Split the dataset such that 10% of each class is used as testing data, and the remainder is used for training your classifier. Use the indices provided by `np.random.choice` with seed set to `27`. **Code is provided do not change it**.
#
# - **Feature Extraction**: Extract suitable features from the images that you think might be relevant in distinguishing each class from the others. Keep in mind the curse of dimensionality when selecting features.
#
# - **Implement a Maximum Likelihood Estimator (MLE)**: Implement a Maximum Likelihood Estimator (MLE) based on your training data.
# - **Report Accuracy and Average F1 Score**: After testing your classifier on the test set, report the **Accuracy** and **Average F1 Score** of your model.

# %%
# !pip install mahotas
# Out:
# Collecting mahotas
#   Downloading mahotas-1.4.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mahotas) (1.25.2)
# Installing collected packages: mahotas
# Successfully installed mahotas-1.4.15

# %%
# Add your libraries here
import numpy as np
from google.colab import drive
import os
import zipfile
import tifffile
import mahotas as mh
from scipy.stats import skew, kurtosis
import matplotlib.pyplot as plt

# %%
# DO NOT CHANGE THIS CELL
## Training set indices.
np.random.seed(27)  # Set random seed for reproducibility

# Randomly select indices for the test sets for each class
residential_test_indices = np.random.choice(np.arange(3000), size=300, replace=False)
forest_test_indices = np.random.choice(np.arange(3000), size=300, replace=False)
river_test_indices = np.random.choice(np.arange(2500), size=250, replace=False)

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Path to the zip file in your Google Drive
zip_file_path = '/content/drive/MyDrive/EuroSATallBands.zip'

# Path to extract the dataset
extracted_path = '/content/dataset'

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_path)

# Check the extracted files
extracted_files = os.listdir(extracted_path)
print("Extracted files:", extracted_files)
# Out:
# Mounted at /content/drive
# Extracted files: ['EuroSATallBands']

# %%
def load_images(class_name):
    images = []
    dataset_path = '/content/dataset/EuroSATallBands/ds/images/remote_sensing/otherDatasets/sentinel_2/tif/'
    class_path = os.path.join(dataset_path, class_name)
    for filename in os.listdir(class_path):
        if filename.endswith('.tif'):
            image_path = os.path.join(class_path, filename)
            image = tifffile.imread(image_path)
            images.append(image)
    return images

# Load images for each class
residential_images = load_images('Residential')
river_images = load_images('River')
forest_images = load_images('Forest')

print("Number of residential images:", len(residential_images))
print("Number of river images:", len(river_images))
print("Number of forest images:", len(forest_images))
# Out:
# Number of residential images: 3000
# Number of river images: 2500
# Number of forest images: 3000

# %%
# Function to display images in a row
def display_images(images, title):
    fig, axs = plt.subplots(1, 10, figsize=(20, 4))
    fig.suptitle(title, fontsize=16)

    for i in range(10):
        axs[i].imshow(images[i][:, :, 3])
        axs[i].axis('off')

    plt.show()

# Display the first 5 residential images
display_images(residential_images[:10], 'Residential Images')

# Display the first 5 river images
display_images(river_images[:10], 'River Images')

# Display the first 5 forest images
display_images(forest_images[:10], 'Forest Images')

# %%
# Split the dataset into training and testing sets

'''
creates an array of indices for the residential class that are not in the residential_test_indices array.
It uses np.arange(3000) to create an array of indices from 0 to 2999 (assuming there are 3000 samples in the residential class)
and then uses np.setdiff1d to find the set difference between these indices and the residential_test_indices,
effectively removing the test set indices from the array.
'''
residential_train_indices = np.setdiff1d(np.arange(3000), residential_test_indices)
forest_train_indices = np.setdiff1d(np.arange(3000), forest_test_indices)
river_train_indices = np.setdiff1d(np.arange(2500), river_test_indices)

# Use the indices to create training and testing datasets
residential_train_images = [residential_images[i] for i in residential_train_indices]
residential_test_images = [residential_images[i] for i in residential_test_indices]

forest_train_images = [forest_images[i] for i in forest_train_indices]
forest_test_images = [forest_images[i] for i in forest_test_indices]

river_train_images = [river_images[i] for i in river_train_indices]
river_test_images = [river_images[i] for i in river_test_indices]

# Print the number of images in the training and testing sets for each class
print("Number of residential training images:", len(residential_train_images))
print("Number of residential testing images:", len(residential_test_images))
print("Number of forest training images:", len(forest_train_images))
print("Number of forest testing images:", len(forest_test_images))
print("Number of river training images:", len(river_train_images))
print("Number of river testing images:", len(river_test_images))
# Out:
# Number of residential training images: 2700
# Number of residential testing images: 300
# Number of forest training images: 2700
# Number of forest testing images: 300
# Number of river training images: 2250
# Number of river testing images: 250

# %%
from skimage.feature import graycomatrix, graycoprops
from skimage.measure import shannon_entropy
from skimage.filters import gabor
from scipy.stats import kurtosis, skew
import cv2

def extract_band_statistics(images):
    statistics = []
    for image in images:
        try:
            band_statistics = []
            for band in range(image.shape[2]):
                band_data = image[:, :, band]
                band_mean = np.mean(band_data)
                band_std = np.std(band_data)
                band_min = np.min(band_data)
                band_max = np.max(band_data)
                band_percentiles = np.percentile(band_data, [25, 50, 75])
                band_statistics.extend([band_mean, band_std, band_min, band_max])
                band_statistics.extend(band_percentiles)
                band_skewness = skew(band_data.flatten())
                band_kurtosis = kurtosis(band_data.flatten())
                band_energy = np.sum(np.square(np.abs(band_data))) / band_data.size
                band_statistics.extend([band_skewness, band_kurtosis, band_energy])

                # Spatial Features (Entropy)
                entropy = shannon_entropy(band_data)
                band_statistics.append(entropy)

                # Edge Features (Canny) - New addition
                edges = cv2.Canny(band_data.astype(np.uint8), 50, 150)  # Adjust thresholds as needed
                edge_count = np.count_nonzero(edges)  # Count edge pixels
                edge_prop = edge_count / band_data.size  # Proportion of pixels with edges
                band_statistics.extend([edge_count, edge_prop])
                '''
                # Gabor Filters (Existing code for comparison)

                frequencies = [0.1, 0.5, 1.0, 2.0]
                for freq in frequencies:
                    filt_real, filt_imag = gabor(band_data, frequency=freq)
                    band_mean_real = np.mean(filt_real)
                    band_std_real = np.std(filt_real)
                    band_mean_imag = np.mean(filt_imag)
                    band_std_imag = np.std(filt_imag)

                # Combine features (consider weighting or selecting based on your needs)
                #band_statistics.extend([band_mean_real, band_std_real, band_mean_imag, band_std_imag])
              '''

            statistics.append(band_statistics)
        except Exception as e:
            print(f"Error processing image: {e}")

    return np.array(statistics)




# Extract statistics for each class
residential_statistics_train = extract_band_statistics(residential_train_images)
river_statistics_train = extract_band_statistics(river_train_images)
forest_statistics_train = extract_band_statistics(forest_train_images)

residential_statistics_test = extract_band_statistics(residential_test_images)
river_statistics_test = extract_band_statistics(river_test_images)
forest_statistics_test = extract_band_statistics(forest_test_images)

# %%
# Set labels to each class for the training set
y_residential_train = np.zeros(len(residential_statistics_train))  # Label=0
y_river_train = np.ones(len(river_statistics_train))               # Label=1
y_forest_train = np.full(len(forest_statistics_train), 2)          # Label=2

# Set labels to each class for the test set
y_residential_test = np.zeros(len(residential_statistics_test))  # Label=0
y_river_test = np.ones(len(river_statistics_test))               # Label=1
y_forest_test = np.full(len(forest_statistics_test), 2)          # Label=2

# Combine features and labels for all classes for training set
X_train = np.concatenate((residential_statistics_train, river_statistics_train, forest_statistics_train))
X_test = np.concatenate((residential_statistics_test, river_statistics_test, forest_statistics_test))

# Combine features and labels for all classes for test set
y_train = np.concatenate((y_residential_train, y_river_train, y_forest_train))
y_test = np.concatenate((y_residential_test, y_river_test, y_forest_test))

# Implement Gaussian Naive Bayes classifier from scratch
class GaussianNB:
    def __init__(self):
        self.class_priors = {}
        self.class_means = {}
        self.class_variances = {}

    def fit(self, X, y, epsilon=1e-9):  # Add epsilon to avoid division by zero
        classes = np.unique(y)
        n_samples, n_features = X.shape

        for c in classes:
            X_c = X[y == c]
            self.class_priors[c] = len(X_c) / n_samples
            self.class_means[c] = np.mean(X_c, axis=0)
            self.class_variances[c] = np.var(X_c, axis=0) + epsilon  # Add epsilon to variance
            print("class prior for class: ", c , "is: ", self.class_priors[c])
            print("class mean for class: ", c , "is: ", self.class_means[c])
            print("class variance for class: ", c , "is: ", self.class_variances[c])
            print()

    def _calculate_likelihood(self, x, mean, variance):
        exponent = -0.5 * ((x - mean) ** 2 / (2 * variance))
        likelihood = (1 / np.sqrt(2 * np.pi * variance)) * np.exp(exponent)
        return likelihood

    def predict(self, X):
        predictions = []
        for x in X:
            posteriors = []
            for c in self.class_priors:
                prior = np.log(self.class_priors[c])
                likelihood = self._calculate_likelihood(x, self.class_means[c], self.class_variances[c])
                if np.any(likelihood == 0):  # Check for zero likelihood values
                    # If likelihood contains zeros, set the corresponding posteriors to -inf
                    posterior = -np.inf
                else:
                    likelihood = np.log(likelihood)
                    posterior = prior + np.sum(likelihood)
                posteriors.append(posterior)
            predicted_class = np.argmax(posteriors)
            predictions.append(predicted_class)
        return np.array(predictions)

# Train the Gaussian Naive Bayes classifier
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# Predict the labels for the test set
y_pred = gnb.predict(X_test)

# Calculate accuracy
accuracy = np.mean(y_pred == y_test)

tp=0
fp=0
fn=0

# Calculate true positives (tp), false negatives (fn), and false positives (fp) for each class
for c in np.unique(y_test):
    tp_c = np.sum((y_pred == y_test) & (y_pred == c))
    fp_c = np.sum((y_pred != y_test) & (y_pred == c))
    fn_c = np.sum((y_pred != y_test) & (y_pred != c))
    tp += tp_c
    fp += fp_c
    fn += fn_c

# Calculate precision, recall, and F1 score
if tp == 0:
    precision = 0.0
    recall = 0.0
    f1 = 0.0
else:
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1 = 2 * (precision * recall) / (precision + recall)

print("Accuracy:", accuracy)
print("Average F1 Score:", f1)
# Out:
# class prior for class:  0.0 is:  0.35294117647058826
# class mean for class:  0.0 is:  [1.45727236e+03 5.79732067e+01 1.31760667e+03 1.66316519e+03
#  1.42217046e+03 1.45610130e+03 1.48911574e+03 3.79933838e-01
#  1.90684826e+00 3.29043508e+04 7.47015045e+00 2.52647778e+02
#  6.16815864e-02 1.21249016e+03 1.94389567e+02 8.63711481e+02
#  3.36505148e+03 1.08525944e+03 1.18319222e+03 1.30073176e+03
#  2.73007690e+00 3.78142001e+01 3.27189823e+04 9.02914280e+00
#  1.52141296e+03 3.71438712e-01 1.11283940e+03 2.16510318e+02
#  6.83447037e+02 3.44314037e+03 9.74863704e+02 1.08131037e+03
#  1.21023204e+03 2.64150080e+00 3.68102592e+01 3.27300639e+04
#  9.18677649e+00 1.52922222e+03 3.73345269e-01 1.07360761e+03
#  3.14070184e+02 4.73095556e+02 3.88185704e+03 8.59446759e+02
#  1.04003907e+03 1.24097176e+03 1.89340978e+00 2.51465050e+01
#  3.27903812e+04 9.73034135e+00 1.52814741e+03 3.73082863e-01
#  1.28683446e+03 1.81624319e+02 8.24822593e+02 2.36396630e+03
#  1.17621898e+03 1.27671407e+03 1.38074593e+03 1.08228577e+00
#  7.65032374e+00 3.27543368e+04 9.04240529e+00 1.40330741e+03
#  3.42604348e-01 1.98052032e+03 2.67579768e+02 1.26672185e+03
#  3.25516037e+03 1.81014148e+03 1.95512037e+03 2.12261667e+03
#  7.52299713e-01 4.36670871e+00 3.29167639e+04 9.58825021e+00
#  1.49992000e+03 3.66191406e-01 2.28713290e+03 3.43730887e+02
#  1.40840704e+03 3.84717333e+03 2.06499296e+03 2.24891704e+03
#  2.46848407e+03 7.48261999e-01 3.67889819e+00 3.29606785e+04
#  9.87025605e+00 1.51157667e+03 3.69037272e-01 2.18718689e+03
#  5.05749216e+02 9.03007037e+02 5.08380185e+03 1.83726657e+03
#  2.13894019e+03 2.49005435e+03 8.52806367e-01 8.42509655e+00
#  3.29462047e+04 1.03722280e+01 1.53066815e+03 3.73698278e-01
#  6.66463560e+02 6.27066275e+01 5.24296296e+02 8.77598519e+02
#  6.26872500e+02 6.59542407e+02 6.98724537e+02 5.03362385e-01
#  1.57696677e+00 3.28128541e+04 7.48771118e+00 2.65323333e+02
#  6.47762044e-02 1.23123428e+01 9.93598790e-01 9.80037037e+00
#  1.49133333e+01 1.16770370e+01 1.23070370e+01 1.29474074e+01
#  5.08029622e-03 1.62079146e-02 1.64498812e+02 1.92513916e+00
#  0.00000000e+00 0.00000000e+00 1.97332909e+03 2.83739762e+02
#  1.19632889e+03 3.36806370e+03 1.79920833e+03 1.96209333e+03
#  2.12961639e+03 6.89088650e-01 4.93359487e+00 3.29410473e+04
#  9.63516219e+00 1.46393556e+03 3.57406141e-01 1.38024347e+03
#  2.74969411e+02 6.77403333e+02 2.76658630e+03 1.20882056e+03
#  1.37427185e+03 1.53890806e+03 6.67805949e-01 5.19596673e+00
#  3.28216664e+04 9.60235190e+00 1.45817815e+03 3.56000524e-01
#  2.47008517e+03 3.88150101e+02 1.48730148e+03 4.17241519e+03
#  2.21772213e+03 2.42476315e+03 2.67582472e+03 7.18591712e-01
#  3.19631791e+00 3.29580440e+04 1.00048147e+01 1.51469741e+03
#  3.69799172e-01]
# class variance for class:  0.0 is:  [3.09857258e+04 7.60617748e+02 3.09029927e+04 5.82799868e+04
#  3.06830026e+04 3.11622237e+04 3.21522482e+04 1.14563575e+00
#  1.65023956e+01 3.84116584e+05 3.56366100e-01 2.35144911e+04
#  1.40157389e-03 3.75543841e+04 6.26494585e+03 3.05946534e+04
#  5.90678563e+06 3.13399239e+04 3.68697971e+04 4.53433261e+04
#  1.49154743e+01 2.02721827e+04 1.10592584e+05 2.05937492e-01
#  1.05176391e+03 6.26910140e-05 5.39404661e+04 7.83421111e+03
#  3.10746546e+04 6.61846713e+06 4.00224667e+04 5.15161740e+04
#  6.87883269e+04 1.44727857e+01 1.89908366e+04 1.02762062e+05
#  2.00512843e-01 6.60058765e+02 3.93435682e-05 1.17903354e+05
#  1.23342970e+04 3.33617368e+04 9.50001141e+06 9.35281800e+04
#  1.19284959e+05 1.52198909e+05 1.05044644e+01 1.14681427e+04
#  1.16542837e+05 1.64976841e-01 6.85782716e+02 4.08768352e-05
#  1.09266041e+05 5.79693445e+03 6.19746222e+04 1.37910556e+06
#  9.47208408e+04 1.12107557e+05 1.30450379e+05 3.25380063e+00
#  6.20773560e+02 1.09966899e+05 2.28195878e-01 8.00014476e+03
#  4.76846787e-04 1.23317244e+05 7.35361564e+03 1.37941174e+05
#  1.39958847e+06 1.28498171e+05 1.33955664e+05 1.34005387e+05
#  2.02661094e+00 3.19069947e+02 1.10374008e+05 8.77092398e-02
#  1.13057286e+03 6.73883937e-05 1.63378759e+05 1.29537973e+04
#  1.83871425e+05 1.53409916e+06 1.71875909e+05 1.77210766e+05
#  1.78830195e+05 1.64333167e+00 2.33276019e+02 1.05784238e+05
#  8.95574585e-02 7.39252270e+02 4.40638690e-05 1.56940541e+05
#  1.57625447e+04 1.37130427e+05 8.77848590e+06 1.70717833e+05
#  1.74475695e+05 1.74351259e+05 3.15239911e+00 1.84514379e+03
#  9.72584432e+04 5.11294753e-02 5.32554319e+02 3.17437110e-05
#  5.29773147e+04 1.44227441e+03 3.76067967e+04 1.04390596e+05
#  4.81916028e+04 5.29938311e+04 5.86890828e+04 1.01850689e+00
#  1.19052714e+01 4.13474353e+06 4.66158289e-01 4.07672529e+04
#  2.42991863e-03 1.17595449e+01 1.58244160e-01 1.00190369e+01
#  1.72502667e+01 1.11334727e+01 1.17966542e+01 1.27276044e+01
#  1.63568832e-01 1.90819795e+00 2.25567708e+04 1.59955854e-01
#  1.00000000e-09 1.00000000e-09 2.21415694e+05 1.29443339e+04
#  1.80332832e+05 2.62386289e+06 2.03465995e+05 2.32280422e+05
#  2.58048175e+05 2.49337200e+00 3.18019481e+02 1.15080821e+05
#  1.43074853e-01 3.07108622e+03 1.83052003e-04 1.65321037e+05
#  1.23261960e+04 8.81542310e+04 2.40261596e+06 1.43855030e+05
#  1.72046700e+05 2.02325898e+05 2.62076386e+00 3.33732932e+02
#  1.20771799e+05 1.80636629e-01 4.38860937e+03 2.61582503e-04
#  1.95179335e+05 1.67536405e+04 2.29003551e+05 1.70422093e+06
#  2.07556509e+05 2.11490791e+05 2.13194356e+05 1.44215389e+00
#  1.79193296e+02 1.06238869e+05 9.22245201e-02 6.76383623e+02
#  4.03166056e-05]
#
# class prior for class:  1.0 is:  0.29411764705882354
# class mean for class:  1.0 is:  [ 1.30565693e+03  6.87860578e+01  1.20735333e+03  1.52148178e+03
#   1.25192156e+03  1.29389533e+03  1.34736100e+03  7.77897218e-01
#   9.31202977e-01  3.28441485e+04  7.28046481e+00  2.05574667e+02
#   5.01891276e-02  1.03915931e+03  1.48018609e+02  8.34473778e+02
#   2.01779778e+03  9.34584444e+02  1.00712644e+03  1.10899689e+03
#   1.75973898e+00  9.84690733e+00  3.26677757e+04  8.13385536e+00
#   1.24479556e+03  3.03905165e-01  9.28049316e+02  1.96509609e+02
#   6.06829333e+02  2.02730578e+03  7.83688667e+02  9.01135333e+02
#   1.03614300e+03  1.12174040e+00  4.91915286e+00  3.27842017e+04
#   8.63855694e+00  1.27241022e+03  3.10647027e-01  7.16108399e+02
#   2.76911762e+02  3.75818222e+02  2.21083067e+03  5.12812778e+02
#   6.44143778e+02  8.48964000e+02  1.64790830e+00  5.86535501e+00
#   3.30104184e+04  8.78593308e+00  1.26228044e+03  3.08173937e-01
#   9.31840127e+02  3.10948637e+02  4.46591556e+02  1.89567378e+03
#   6.77855556e+02  9.28761778e+02  1.14462711e+03  3.11102149e-01
#   2.99617064e-01  3.26879045e+04  9.19741221e+00  1.09533111e+03
#   2.67414822e-01  1.72091765e+03  7.77063142e+02  4.59534667e+02
#   3.34954667e+03  1.07164367e+03  1.79953933e+03  2.33073033e+03
#  -2.30102176e-01 -6.39479646e-01  3.28574955e+04  9.99213757e+00
#   1.26395333e+03  3.08582357e-01  2.07658379e+03  9.98341983e+02
#   4.82328000e+02  4.19690000e+03  1.23740556e+03  2.15483200e+03
#   2.86058444e+03 -1.74413992e-01 -6.65262157e-01  3.28531450e+04
#   1.02380282e+01  1.29939778e+03  3.17235786e-01  1.99520071e+03
#   1.08153216e+03  3.69969778e+02  4.60780356e+03  1.06866344e+03
#   2.03497311e+03  2.84322456e+03 -9.04658364e-02 -6.30569955e-01
#   3.29394476e+04  1.01493959e+01  1.36642933e+03  3.33600911e-01
#   5.96273400e+02  2.38403212e+02  1.87863556e+02  1.02535467e+03
#   3.87967778e+02  6.21829111e+02  7.93709222e+02 -1.85792248e-01
#  -8.83187268e-01  3.07461551e+04  8.98589187e+00  6.33419556e+02
#   1.54643446e-01  1.05280770e+01  1.46390252e+00  7.24044444e+00
#   1.41768889e+01  9.45811111e+00  1.05202222e+01  1.15527778e+01
#   5.50083447e-02 -2.86951040e-01  1.28461743e+02  2.41827924e+00
#   1.33333333e-02  3.25520833e-06  1.30547965e+03  7.18847758e+02
#   1.64818667e+02  2.92548356e+03  6.99436778e+02  1.37165133e+03
#   1.85733467e+03 -1.59557056e-01 -5.82933538e-01  3.04987956e+04
#   9.95091905e+00  1.20542933e+03  2.94294271e-01  7.20550812e+02
#   4.42572026e+02  8.85684444e+01  2.06270178e+03  3.49442333e+02
#   7.04055778e+02  1.02339411e+03  3.67580510e-01  1.45542032e-01
#   2.79139971e+04  9.50000708e+00  1.11198711e+03  2.71481228e-01
#   2.25169376e+03  1.14564554e+03  4.14408444e+02  4.57778978e+03
#   1.28959156e+03  2.35759022e+03  3.16244956e+03 -2.26628210e-01
#  -6.90474914e-01  3.28730710e+04  1.03369620e+01  1.31645022e+03
#   3.21398980e-01]
# class variance for class:  1.0 is:  [2.33441835e+04 2.12387708e+03 2.26576703e+04 6.15277750e+04
#  2.29388670e+04 2.35787434e+04 2.63216889e+04 7.22940788e-01
#  1.08448734e+01 3.07902433e+06 6.46564493e-01 2.45046551e+04
#  1.46059226e-03 2.02918547e+04 6.62269353e+03 1.37543462e+04
#  9.36763935e+05 1.74709620e+04 2.20984197e+04 3.17902000e+04
#  3.11218788e+00 2.11999284e+03 1.01763388e+06 3.28093161e-01
#  2.66919884e+04 1.59096749e-03 2.25972037e+04 7.59090503e+03
#  9.93559487e+03 8.87473747e+05 1.84119489e+04 2.47325082e+04
#  3.93560919e+04 1.76704807e+00 3.50503108e+02 1.82299751e+06
#  2.27791802e-01 2.72816171e+04 1.62611209e-03 4.44976285e+04
#  1.97658314e+04 7.71980473e+03 1.18231807e+06 2.11046438e+04
#  4.77225163e+04 1.02985512e+05 1.54271866e+00 2.71217253e+02
#  6.12376183e+06 4.38988628e-01 2.86616800e+04 1.70837026e-03
#  4.93953307e+04 1.38675760e+04 2.08141225e+04 3.89962896e+05
#  6.04076798e+04 6.33936784e+04 7.72061493e+04 6.60019738e-01
#  6.19625748e+00 5.79120819e+06 2.67823563e-01 2.82724455e+04
#  1.68517007e-03 2.23684888e+05 4.08644509e+04 4.58424204e+04
#  3.60723314e+05 4.54122261e+05 4.03493078e+05 2.58101731e+05
#  4.08383621e-01 1.29007942e+00 5.00663694e+06 2.55502518e-01
#  3.25196605e+04 1.93832381e-03 3.95575218e+05 7.19170713e+04
#  6.10533040e+04 6.44076944e+05 7.09833194e+05 6.93109160e+05
#  5.01645221e+05 3.88756084e-01 1.25137766e+00 4.09665905e+06
#  2.64977624e-01 3.17996662e+04 1.89540881e-03 3.77254155e+05
#  6.64019207e+04 2.89381155e+04 8.50159128e+05 6.90073908e+05
#  7.98092182e+05 4.97648702e+05 4.16277206e-01 4.09013788e+00
#  5.57197127e+06 3.33736334e-01 2.66442717e+04 1.58812335e-03
#  6.30093008e+04 1.17628062e+04 1.84163072e+04 1.44370645e+05
#  6.23777344e+04 8.05691051e+04 9.41018550e+04 2.73176139e-01
#  5.22513660e-01 1.09460132e+07 3.41261121e-01 4.61967493e+04
#  2.75354183e-03 1.48572782e+01 6.21048562e-01 9.33018647e+00
#  4.29491548e+01 1.25412731e+01 1.49788133e+01 1.78802978e+01
#  2.03692532e-01 8.67375842e+00 3.24362710e+04 1.96060292e-01
#  3.99822223e-01 2.48312615e-08 1.72492520e+05 3.77077212e+04
#  1.41380222e+04 5.41266175e+05 3.24888161e+05 3.00299288e+05
#  2.37237742e+05 3.88244861e-01 1.33170399e+00 1.18354487e+07
#  2.64419897e-01 3.01968815e+04 1.79987539e-03 7.80262342e+04
#  2.80724415e+04 4.49371465e+03 6.17690560e+05 7.81731413e+04
#  1.09428633e+05 1.57041154e+05 4.86524502e-01 4.19107445e+00
#  2.05637083e+07 3.48346183e-01 3.25100394e+04 1.93775035e-03
#  4.90299570e+05 8.30039751e+04 5.31651981e+04 6.66286993e+05
#  9.41411813e+05 9.05512931e+05 5.97670896e+05 3.96288398e-01
#  1.13991036e+00 4.79168471e+06 2.53658327e-01 3.02598200e+04
#  1.80362682e-03]
#
# class prior for class:  2.0 is:  0.35294117647058826
# class mean for class:  2.0 is:  [ 1.11069395e+03  8.08505228e+00  1.09474370e+03  1.14037185e+03
#   1.10514028e+03  1.10995259e+03  1.11528806e+03  6.44346876e-01
#   1.92252934e+00  3.27341520e+04  4.63824207e+00  1.94144444e+01
#   4.73985460e-03  8.11851390e+02  2.34536190e+01  7.45339259e+02
#   1.01378222e+03  7.97861944e+02  8.10005370e+02  8.22769259e+02
#   1.58886621e+00  1.27552523e+01  3.29555718e+04  6.25957825e+00
#   1.27009667e+03  3.10082194e-01  6.86808281e+02  4.61634242e+01
#   5.42767778e+02  9.75464815e+02  6.57632130e+02  6.84750741e+02
#   7.12485741e+02  8.39733837e-01  5.29071861e+00  3.29807646e+04
#   7.30032730e+00  1.47914667e+03  3.61119792e-01  4.15163330e+02
#   4.53323851e+01  3.16328519e+02  8.41328148e+02  3.89294259e+02
#   4.08555926e+02  4.31067130e+02  2.51204676e+00  2.03386850e+01
#   3.28805298e+04  6.92579273e+00  1.36899630e+03  3.34227611e-01
#   7.46161460e+02  6.97637169e+01  5.68435926e+02  1.03450444e+03
#   6.99657593e+02  7.42715556e+02  7.87273889e+02  6.20572260e-01
#   2.38959813e+00  3.28783745e+04  7.80582457e+00  1.01790296e+03
#   2.48511466e-01  2.09731143e+03  2.35317722e+02  1.45518667e+03
#   2.82432148e+03  1.93545546e+03  2.09289463e+03  2.25338657e+03
#   1.68696206e-01  5.60059482e-01  3.29655217e+04  9.44809790e+00
#   1.39780148e+03  3.41260127e-01  2.68652316e+03  3.25435757e+02
#   1.81702926e+03  3.68015148e+03  2.46079435e+03  2.67833148e+03
#   2.90210241e+03  1.91921833e-01  5.30284423e-01  3.29120350e+04
#   9.82257874e+00  1.45310630e+03  3.54762279e-01  2.63216141e+03
#   4.21263533e+02  1.30453296e+03  4.12892222e+03  2.34654889e+03
#   2.62424519e+03  2.90908417e+03  1.42133874e-01  6.36844732e-01
#   3.29181994e+04  1.01654742e+01  1.53218926e+03  3.74069643e-01
#   8.22075032e+02  7.14351471e+01  6.58158889e+02  9.96461481e+02
#   7.71041389e+02  8.21280556e+02  8.71886481e+02  1.10392452e-01
#   7.72753989e-02  3.28593966e+04  7.72392246e+00  2.53589630e+02
#   6.19115307e-02  9.88806921e+00  9.48838656e-01  7.59222222e+00
#   1.22837037e+01  9.26148148e+00  9.87092593e+00  1.05034259e+01
#   2.51071841e-02 -1.27260312e-01  1.12714285e+02  1.84485968e+00
#   0.00000000e+00  0.00000000e+00  1.31065369e+03  1.80526401e+02
#   8.50666296e+02  1.94552815e+03  1.18952389e+03  1.30758148e+03
#   1.42467139e+03  3.13925963e-01  1.53550414e+00  3.28848670e+04
#   9.04115468e+00  1.20459704e+03  2.94091073e-01  5.34265523e+02
#   8.59083450e+01  3.38083704e+02  9.36860000e+02  4.78321296e+02
#   5.27953519e+02  5.80587685e+02  8.50969980e-01  3.87477337e+00
#   3.28442139e+04  7.99697289e+00  9.28375926e+02  2.26654279e-01
#   3.00324958e+03  3.70774169e+02  2.01420852e+03  4.12489111e+03
#   2.74622324e+03  2.99458074e+03  3.24946583e+03  1.83774159e-01
#   5.31227247e-01  3.28388564e+04  9.96231091e+00  1.46454741e+03
#   3.57555519e-01]
# class variance for class:  2.0 is:  [1.20867291e+04 1.99633507e+01 1.22496432e+04 1.22398847e+04
#  1.21793054e+04 1.21199816e+04 1.20493743e+04 1.10165667e+00
#  3.74709057e+01 5.67743965e+07 4.11755062e-01 2.52304935e+03
#  1.50386460e-04 7.10592451e+03 9.17282413e+01 7.44303231e+03
#  2.25866615e+04 7.13645629e+03 7.15509877e+03 7.18300759e+03
#  3.48193362e+00 6.69077259e+02 3.04310398e+06 1.58881397e-01
#  4.05528125e+04 2.41713698e-03 7.56363394e+03 3.00596731e+02
#  6.13775607e+03 3.51309851e+04 7.05082053e+03 7.71794083e+03
#  8.55102790e+03 1.41284703e+00 1.47879123e+02 4.81478420e+05
#  2.18138860e-01 5.22560441e+03 3.11471295e-04 4.54904031e+03
#  5.97764042e+02 3.39609467e+03 8.66640360e+04 3.84028448e+03
#  4.29931224e+03 5.18712811e+03 5.13354506e+00 1.33890218e+03
#  1.96305020e+07 3.13551726e-01 2.12065037e+04 1.26400712e-03
#  3.12753491e+04 9.33068892e+02 2.09440096e+04 5.54740078e+04
#  2.88118827e+04 3.20437493e+04 3.56639273e+04 1.00744537e+00
#  3.01357415e+01 6.27704763e+05 3.37330228e-01 2.73492521e+04
#  1.63014345e-03 1.90238204e+05 7.52977709e+03 1.70659090e+05
#  2.42078736e+05 1.90508675e+05 1.99824954e+05 2.09265091e+05
#  4.65756283e-01 5.10119403e+00 1.22526109e+05 2.76121479e-01
#  8.31294133e+03 4.95490915e-04 3.44957118e+05 1.44784672e+04
#  2.85251192e+05 4.36656638e+05 3.43108351e+05 3.66284507e+05
#  3.85810870e+05 4.73553921e-01 4.50351156e+00 1.17249054e+05
#  2.57535821e-01 5.56359426e+03 3.31617059e-04 3.38786307e+05
#  1.67782496e+04 2.52555294e+05 4.50874152e+05 3.42497801e+05
#  3.67124105e+05 3.83985704e+05 3.74966674e-01 3.41520972e+00
#  1.07891125e+05 1.63751933e-01 5.28532699e+02 3.15040038e-05
#  1.16555084e+05 1.59732163e+03 8.15198055e+04 1.59034117e+05
#  1.06591977e+05 1.18023723e+05 1.29718285e+05 4.53364119e-01
#  2.60274141e+00 4.62204522e+06 6.13434699e-01 2.82750472e+04
#  1.68532514e-03 1.38111711e+01 2.28906612e-01 9.54519877e+00
#  2.26535863e+01 1.19741274e+01 1.37878769e+01 1.60486225e+01
#  1.12503412e-01 1.01247041e+00 1.87106943e+04 1.76742340e-01
#  1.00000000e-09 1.00000000e-09 8.48221651e+04 5.18170945e+03
#  1.03486655e+05 1.42762868e+05 9.61478748e+04 8.93228647e+04
#  8.49483461e+04 8.94841573e-01 1.46298158e+01 1.26911202e+05
#  3.40425088e-01 1.88955458e+04 1.12626329e-03 1.77619186e+04
#  1.46179781e+03 1.73722315e+04 9.13943234e+04 1.74357692e+04
#  1.75538348e+04 1.92753680e+04 1.61210721e+00 6.87490466e+01
#  2.02397833e+06 3.56014449e-01 2.86125828e+04 1.70544383e-03
#  4.16262593e+05 1.94400889e+04 3.65521727e+05 5.05375289e+05
#  4.19804396e+05 4.44221069e+05 4.64210039e+05 4.81833435e-01
#  4.64619617e+00 1.22203300e+05 2.54184528e-01 4.73744109e+03
#  2.82374493e-04]
#
# Accuracy: 0.9847058823529412
# Average F1 Score: 0.9772329246935202

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Residential', 'River', 'Forest'],
            yticklabels=['Residential', 'River', 'Forest'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# features ===> Band statistics ===> Acc=96.9
#               color histogram ===> Acc=61.8
#           ===> Band statistics + color histogram ===> Acc=92.7
#                Band statistics [Add skew & kurtosis & energy] ===> Acc=97.2

# %%
#The likelihood equation used in the Gaussian Naive Bayes classifier is derived from the assumption that
#each feature within each class follows a Gaussian (normal) distribution.
#This assumption is fundamental to the Naive Bayes algorithm,
#and it simplifies the model by assuming that the features are conditionally independent given the class label.

# %% [markdown]
# ### Grading Rubric (Total: 10 Marks)
#
# The lab is graded based on the following criteria:
#
# 1. **Data Loading and Preparation (2 Marks)**
#    - Correctly loads images for the residential, river, and forest classes. (0.5 Marks)
#    - Accurately splits the dataset into training and testing subsets and clearly shows this split. (1.5 Marks)
#
# 2. **Feature Extraction (2 Marks)**
#    - Implements feature extraction appropriately, considering the curse of dimensionality. (1 Mark)
#    - Extracts and justifies the selection of features relevant to distinguishing the classes. (1 Mark)
#
# 3. **Implementation of MLE Classifier (3 Marks)**
#    - Correctly calculates and clearly shows class priors and class-specific parameters. (1 Mark)
#    - Accurately computes likelihoods using the likelihood equation (probability density function) and classifies based on maximum likelihood. Must clearly show these calculations and explain the choice of likelihood equation. (2 Marks)
#
# 4. **Model Evaluation and Understanding (3 Marks)**
#    - Shows **confusion matrix** and correctly calculates and clearly shows the calculations for Accuracy and Average F1 Score. (1 Mark)
#    - **Comparison amongst your peers.** Compares the model's performance against those of peers to identify strengths and areas for improvement. (2 Marks)
#
# Each section of the lab will be evaluated on completeness, and correctness in approach and analysis. Part of the rubric also includes the student's ability to explain and justify their choices and results.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this project. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed projects and wish you the best of luck!
